# %%
# %pip install numpy matplotlib pandas fsspec huggingface_hub
# Out:
# Requirement already satisfied: numpy in c:\users\cenal\documents\calepin\data\pandas\venv\lib\site-packages (2.3.4)
# Requirement already satisfied: matplotlib in c:\users\cenal\documents\calepin\data\pandas\venv\lib\site-packages (3.10.7)
# Requirement already satisfied: pandas in c:\users\cenal\documents\calepin\data\pandas\venv\lib\site-packages (2.3.3)
# Requirement already satisfied: fsspec in c:\users\cenal\documents\calepin\data\pandas\venv\lib\site-packages (2025.10.0)
# Requirement already satisfied: huggingface_hub in c:\users\cenal\documents\calepin\data\pandas\venv\lib\site-packages (1.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\cenal\documents\calepin\data\pandas\venv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\cenal\documents\calepin\data\pandas\venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\cenal\documents\calepin\data\pandas\venv\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\cenal\documents\calepin\data\pandas\venv\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\cenal\documents\calepin\data\pandas\venv\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\cenal\documents\calepin\data\pandas\venv\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\cenal\documents\calepin\data\pandas\venv\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\cenal\documents\calepin\data\pandas\venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\cenal\documents\calepin\data\pandas\venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\cenal\documents\calepin\data\pandas\venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: filelock in c:\users\cenal\documents\calepin\data\pandas\venv\lib\site-packages (from huggingface_hub) (3.20.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in c:\users\cenal\documents\calepin\data\pandas\venv\lib\site-packages (from huggingface_hub) (1.2.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\cenal\documents\calepin\data\pandas\venv\lib\site-packages (from huggingface_hub) (0.28.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\cenal\documents\calepin\data\pandas\venv\lib\site-packages (from huggingface_hub) (6.0.3)
# Requirement already satisfied: shellingham in c:\users\cenal\documents\calepin\data\pandas\venv\lib\site-packages (from huggingface_hub) (1.5.4)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\cenal\documents\calepin\data\pandas\venv\lib\site-packages (from huggingface_hub) (4.67.1)
# Requirement already satisfied: typer-slim in c:\users\cenal\documents\calepin\data\pandas\venv\lib\site-packages (from huggingface_hub) (0.20.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\cenal\documents\calepin\data\pandas\venv\lib\site-packages (from huggingface_hub) (4.15.0)
# Requirement already satisfied: anyio in c:\users\cenal\documents\calepin\data\pandas\venv\lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub) (4.11.0)
# Requirement already satisfied: certifi in c:\users\cenal\documents\calepin\data\pandas\venv\lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\cenal\documents\calepin\data\pandas\venv\lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub) (1.0.9)
# Requirement already satisfied: idna in c:\users\cenal\documents\calepin\data\pandas\venv\lib\site-packages (from httpx<1,>=0.23.0->huggingface_hub) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\cenal\documents\calepin\data\pandas\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub) (0.16.0)
# Requirement already satisfied: six>=1.5 in c:\users\cenal\documents\calepin\data\pandas\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: colorama in c:\users\cenal\documents\calepin\data\pandas\venv\lib\site-packages (from tqdm>=4.42.1->huggingface_hub) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\cenal\documents\calepin\data\pandas\venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->huggingface_hub) (1.3.1)
# Requirement already satisfied: click>=8.0.0 in c:\users\cenal\documents\calepin\data\pandas\venv\lib\site-packages (from typer-slim->huggingface_hub) (8.3.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
df = pd.read_csv("hf://datasets/Twitter/TwitterFollowGraph/TwitterFollowGraph.csv.zip")

# %%
df.head()
# Out:
#    user_index  author_index  time_chunk
# 0     3593395       2261177         194
# 1     3717054       3828817         200
# 2     9256841        824138         699
# 3     6609334        821321         256
# 4     3032127       3087953         561

# %%
df["period"] = df["time_chunk"].apply(func=lambda x: np.trunc(x/10))
df["counter"] = 1
df = df[["counter","period"]]

# %%
df.groupby(["period"])["period"].count().plot()
# Out:
# <Axes: xlabel='period'>
